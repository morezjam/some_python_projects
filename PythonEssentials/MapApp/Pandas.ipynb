# %%
import pandas
df = pandas.read_csv("10.3 supermarkets-semi-colons.txt",sep=";")
df
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df.columns = ["id", "ad", "city", "state", "country", "name", "emp"]
df
# Out:
#    id               ad           city             state country          name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    emp
# 0    8
# 1   15
# 2   25
# 3   10
# 4   12
# 5   20

# %%
df.set_index(df.id)
df
# Out:
#    id               ad           city             state country          name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    emp
# 0    8
# 1   15
# 2   25
# 3   10
# 4   12
# 5   20

# %%
df.set_index(["id"], inplace = True, drop=False)
df
# Out:
#     id               ad           city             state country  \
# id
# 1    1     3666 21st St  San Francisco          CA 94114     USA
# 2    2   735 Dolores St  San Francisco          CA 94119     USA
# 3    3      332 Hill St  San Francisco  California 94114     USA
# 4    4     3995 23rd St  San Francisco          CA 94114     USA
# 5    5  1056 Sanchez St  San Francisco        California     USA
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#             name  emp
# id
# 1        Madeira    8
# 2    Bready Shop   15
# 3    Super River   25
# 4     Ben's Shop   10
# 5        Sanchez   12
# 6     Richvalley   20

# %%
df.set_index(["id"], inplace = True, drop = True)
df
# Out:
#                  ad           city             state country          name  \
# id
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     emp
# id
# 1     8
# 2    15
# 3    25
# 4    10
# 5    12
# 6    20

# %%
df.loc["3":"6", "city":"name"]
# Out:
#              city             state country          name
# id
# 3   San Francisco  California 94114     USA   Super River
# 4   San Francisco          CA 94114     USA    Ben's Shop
# 5   San Francisco        California     USA       Sanchez
# 6   San Francisco          CA 94114     USA    Richvalley

# %%
df.loc[ df.state == "California" ].loc[ df.country == "USA" ]
# Out:
#                  ad           city       state country     name  emp
# id
# 5   1056 Sanchez St  San Francisco  California     USA  Sanchez   12

# %%
df.drop("ad", axis=1)
# Out:
#              city             state country          name  emp
# id
# 1   San Francisco          CA 94114     USA       Madeira    8
# 2   San Francisco          CA 94119     USA   Bready Shop   15
# 3   San Francisco  California 94114     USA   Super River   25
# 4   San Francisco          CA 94114     USA    Ben's Shop   10
# 5   San Francisco        California     USA       Sanchez   12
# 6   San Francisco          CA 94114     USA    Richvalley   20

# %%
df.drop([1,2,5], axis= 0)
# Out:
#                  ad           city             state country          name  \
# id
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     emp
# id
# 3    25
# 4    10
# 6    20

# %%
df["cont"] = ["North America"] * df.shape[0]
df
# Out:
#                  ad           city             state country          name  \
# id
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     emp           cont
# id
# 1     8  North America
# 2    15  North America
# 3    25  North America
# 4    10  North America
# 5    12  North America
# 6    20  North America

# %%
# adding new row

def add_row(df, values):
    df_t = df.T
    df_t[df.index.max() + 1] = values
    return df_t.T

add_row(df, ["234 StreetBok", "LA", "CA", "USA", "Smith", 8, "North America"])
# Out:
#                  ad           city             state country          name  \
# id
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
# 7     234 StreetBok             LA                CA     USA         Smith
#
#    emp           cont
# id
# 1    8  North America
# 2   15  North America
# 3   25  North America
# 4   10  North America
# 5   12  North America
# 6   20  North America
# 7    8  North America

# %%
# Out:
# 6
